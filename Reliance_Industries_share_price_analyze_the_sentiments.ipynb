# %% [markdown]
# <a href="https://colab.research.google.com/github/gehad-eng/APIMapper/blob/master/Reliance_Industries_share_price_analyze_the_sentiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import openai
from GoogleNews import GoogleNews
from datetime import datetime, timedelta
import requests
from bs4 import BeautifulSoup
import time

# Set up API key for OpenAI if you're using it for something else
key='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'
openai.api_key = key

# Initialize GoogleNews
googlenews = GoogleNews()

# Set language, period, and time range for news search
googlenews.set_lang('en')
googlenews.set_period('3d')
data_end = datetime.now() - timedelta(days=10)
data_start = datetime.strftime(data_end, '%m/%d/%Y')
data_end = datetime.strftime(data_end, '%m/%d/%Y')
googlenews.set_time_range(data_start, data_end)
googlenews.set_encode('utf-8')

# Search for news related to "Reliance Industries share price"
googlenews.get_news('Reliance Industries share price')

# Get top news links
top_news = googlenews.results(sort=True)[:15]

# List to store news content and sentiments
news_content_with_sentiments = []

# Function to analyze sentiment
def analyze_sentiment(text):
    # You can use OpenAI's API or any other sentiment analysis tool here
    # For this example, let's assume a placeholder sentiment analysis function
    # sentiment = openai.Completion.create(engine="text-davinci-003", prompt=text, max_tokens=1)
    # return sentiment['choices'][0]['text'].strip()
    return "Positive"  # Placeholder for sentiment analysis result

def scrape_and_analyze(news_url):
    try:
        if not news_url.startswith('http'):
            news_url = 'https://' + news_url
        response = requests.get(news_url)
        soup = BeautifulSoup(response.text, 'html.parser')
        page_content = ""
        for paragraph in soup.find_all('p'):
            page_content += paragraph.get_text() + " "
            time.sleep(1)
        sentiment = analyze_sentiment(page_content)
        return {"url": news_url, "content": page_content, "sentiment": sentiment}
    except Exception as e:
        print('Error scraping or analyzing:', e)
        return None

# Loop through top news links, scrape content, and analyze sentiment
for news_link in top_news:
    news_data = scrape_and_analyze(news_link['link'])
    if news_data:
        news_content_with_sentiments.append(news_data)

# Display the results
for news_data in news_content_with_sentiments:
    print("URL:", news_data["url"])
    print("Sentiment:", news_data["sentiment"])
    print("Content:", news_data["content"][:100])  # Displaying only the first 100 characters of content
    print("---------------------------------------------")
# Out:
# URL: https://news.google....?hl=en-US&gl=US&ceid=US%3Aen
# Sentiment: Positive
# Content:       Domestic brokerage firm Anand Rathi has initiated coverage on Suzlon Energy and Inox Wind, ass
# ---------------------------------------------
# URL: https://news.google....?hl=en-US&gl=US&ceid=US%3Aen
# Sentiment: Positive
# Content:       Sam Bankman-Fried, founder of cryptocurrency exchange FTX, was sentenced to 25 years in prison
# ---------------------------------------------
# URL: https://news.google....?hl=en-US&gl=US&ceid=US%3Aen
# Sentiment: Positive
# Content:       In the first collaboration between rival billionaires, Mukesh Ambani's Reliance Industries has
# ---------------------------------------------
# URL: https://news.google....?hl=en-US&gl=US&ceid=US%3Aen
# Sentiment: Positive
# Content:  Astra Microwave Products Share Price Today: Shares of Astra Microwave Products rallied over 14 per
# ---------------------------------------------
# ...
